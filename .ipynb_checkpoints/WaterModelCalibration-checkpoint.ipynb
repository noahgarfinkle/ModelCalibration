# %% [markdown]
# # Water Model Calibration

# %%
import wntr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import scipy as sp
import chaospy as cp

# %% [markdown]
# # Helper Methods

# %%
def extractDataFrame(wn,objType="Pipe"):
    objsDict = {}
    try:
        objIter = wn.pipes()
        if objType == "Junction":
            objIter = wn.junctions()
        for obj in objIter:
            obj = obj[1]
            objDict = obj.todict()
            for k,v in objDict.items():
                if k in objsDict.keys():
                    objsDict[k].append(v)
                else:
                    objsDict[k] = [v]
        objsDF = pd.DataFrame(objsDict)
        return objsDF
    except:
        return objsDict

# %% [markdown]
# # Set up Base (True Model)

# %%
# Create a water network model
inp_file = 'networks/Net3.inp'
wn_true = wntr.network.WaterNetworkModel(inp_file)

# Graph the network
wntr.graphics.plot_network(wn_true, title="True Network")

# Simulate hydraulics
sim_true = wntr.sim.EpanetSimulator(wn_true)
results_true = sim_true.run_sim()

# Plot results on the network
pressure_at_5hr = results_true.node['pressure'].loc[5*3600, :]
wntr.graphics.plot_network(wn_true, node_attribute=pressure_at_5hr, node_size=30, 
                        title='Pressure at 5 hours')
# Out:
# (<matplotlib.collections.PathCollection at 0x1cca64ad588>,
#  <matplotlib.collections.LineCollection at 0x1cca64b2748>)

# %%
class ResultAnalyzer():
    def __init__(self,results,convertResultsToHours=True):
        self.results = results
        
        # programatically set nodes
        for nodeKey in results.node.keys():
            self.__dict__[nodeKey] = results.node[nodeKey].T
        
        # progrmatically set links
        for linkKey in results.link.keys():
            self.__dict__[linkKey] = results.link[linkKey].T
        
        if convertResultsToHours:
            self.convertResultsToHours()
            
    def help(self):
        return list(self.__dict__.keys())
        
    def convertResultsToHours(self):
        for prop,value in self.__dict__.items():
            if type(value) == pd.DataFrame:
                value.columns = [float(seconds)/3600.0 for seconds in value.columns]
                
    def returnResult(self,resultType,resultLocationID,time):
        if resultType in self.__dict__.keys():
            resultDF = self.__dict__[resultType]
            if resultLocationID in resultDF.index:
                if time in resultDF.columns:
                    return self.__dict__[resultType].loc[resultLocationID][time]
                else:
                    print(f"{time} is not a valid time")
            else:
                print(f"{resultLocationID} is not a valid element in the network")
        else:
            print(f"{resultType} is not a valid property for ResultAnalyzer")
            return None

# %%
a = ResultAnalyzer(results)

# %%
a.help()
# Out:
# ['results',
#  'demand',
#  'head',
#  'pressure',
#  'quality',
#  'linkquality',
#  'flowrate',
#  'headloss',
#  'velocity',
#  'status',
#  'setting',
#  'frictionfact',
#  'rxnrate']

# %%
a.returnResult("flowrate",'20',.25)
# Out:
# -0.14029883

# %%
pipesDF = extractDataFrame(wn)
pipesDF
# Out:
#     bulk_rxn_coeff     cv  diameter end_node end_node_name  flow  \
# 0             None  False    2.5146       20            20  None
# 1             None  False    2.5146       40            40  None
# 2             None  False    2.5146       50            50  None
# 3             None  False    0.6096       60            60  None
# 4             None  False    0.4572      101           101  None
# ..             ...    ...       ...      ...           ...   ...
# 112           None  False    0.3048      275           275  None
# 113           None  False    0.2032      271           271  None
# 114           None  False    0.7620      123           123  None
# 115           None  False    0.7620      601           601  None
# 116           None  False    0.7620       61            61  None
#
#     initial_setting  initial_status      length link_type  minor_loss name  \
# 0              None               1     30.1752      Pipe         0.0   20
# 1              None               1     30.1752      Pipe         0.0   40
# 2              None               1     30.1752      Pipe         0.0   50
# 3              None               1    375.2088      Pipe         0.0   60
# 4              None               1   4328.1600      Pipe         0.0  101
# ..              ...             ...         ...       ...         ...  ...
# 112            None               1     91.4400      Pipe         0.0  323
# 113            None               1    393.1920      Pipe         0.0  325
# 114            None               1  13868.4000      Pipe         0.0  329
# 115            None               0      0.3048      Pipe         0.0  330
# 116            None               1      0.3048      Pipe         0.0  333
#
#      roughness setting start_node start_node_name  status   tag vertices  \
# 0        199.0    None          3               3       1  None       []
# 1        199.0    None          1               1       1  None       []
# 2        199.0    None          2               2       1  None       []
# 3        140.0    None      River           River       1  None       []
# 4        110.0    None         10              10       1  None       []
# ..         ...     ...        ...             ...     ...   ...      ...
# 112      130.0    None        201             201       1  None       []
# 113      130.0    None        269             269       1  None       []
# 114      140.0    None         61              61       1  None       []
# 115      140.0    None         60              60       0  None       []
# 116      140.0    None        601             601       1  None       []
#
#     wall_rxn_coeff
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ..             ...
# 112           None
# 113           None
# 114           None
# 115           None
# 116           None
#
# [117 rows x 20 columns]

# %%
junctionsDF = extractDataFrame(wn,"Junction")
junctionsDF
# Out:
#     base_demand     coordinates demand  \
# 0      0.000000    (9.0, 27.85)   None
# 1      0.000063  (38.68, 23.76)   None
# 2      0.000000  (29.44, 26.91)   None
# 3      0.000063  (25.46, 10.52)   None
# 4      0.000000   (27.02, 9.81)   None
# ..          ...             ...    ...
# 87     0.000000  (23.38, 12.95)   None
# 88     0.000000  (25.03, 12.14)   None
# 89     0.000000   (25.97, 11.0)   None
# 90     0.000000   (29.16, 7.38)   None
# 91     0.000000   (31.07, 8.29)   None
#
#                                demand_timeseries_list  elevation  head  \
# 0   [<TimeSeries: base=0.0, pattern='1', category=...   44.80560  None
# 1   [<TimeSeries: base=6.30901964e-05, pattern='3'...    9.75360  None
# 2   [<TimeSeries: base=0.0, pattern='1', category=...   39.31920  None
# 3   [<TimeSeries: base=6.30901964e-05, pattern='4'...    3.81000  None
# 4   [<TimeSeries: base=0.0, pattern='1', category=...   40.20312  None
# ..                                                ...        ...   ...
# 87  [<TimeSeries: base=0.0, pattern='1', category=...    6.40080  None
# 88  [<TimeSeries: base=0.0, pattern='1', category=...    0.00000  None
# 89  [<TimeSeries: base=0.0, pattern='1', category=...    1.82880  None
# 90  [<TimeSeries: base=0.0, pattern='1', category=...    2.43840  None
# 91  [<TimeSeries: base=0.0, pattern='1', category=...    3.04800  None
#
#     initial_quality  leak_area leak_demand  leak_discharge_coeff  leak_status  \
# 0               0.0        0.0        None                   0.0        False
# 1               0.0        0.0        None                   0.0        False
# 2               0.0        0.0        None                   0.0        False
# 3               0.0        0.0        None                   0.0        False
# 4               0.0        0.0        None                   0.0        False
# ..              ...        ...         ...                   ...          ...
# 87              0.0        0.0        None                   0.0        False
# 88              0.0        0.0        None                   0.0        False
# 89              0.0        0.0        None                   0.0        False
# 90              0.0        0.0        None                   0.0        False
# 91              0.0        0.0        None                   0.0        False
#
#     minimum_pressure name node_type  nominal_pressure   tag
# 0                0.0   10  Junction              20.0  None
# 1                0.0   15  Junction              20.0  None
# 2                0.0   20  Junction              20.0  None
# 3                0.0   35  Junction              20.0  None
# 4                0.0   40  Junction              20.0  None
# ..               ...  ...       ...               ...   ...
# 87               0.0  267  Junction              20.0  None
# 88               0.0  269  Junction              20.0  None
# 89               0.0  271  Junction              20.0  None
# 90               0.0  273  Junction              20.0  None
# 91               0.0  275  Junction              20.0  None
#
# [92 rows x 16 columns]

# %% [markdown]
# # Set up Altered Model

# %% [markdown]
# # Setting Up

# %%
class Sensor():
    def __init__(self,junctionName):
        self.junctionName = junctionName
        self.timeSeries = []

# %%
class Calibrator():
    def __init__(self,pipeName,distribution):
        self.pipeName = pipeName
        self.prior = distribution # type of distribution
        self.values = []

# %%
c1 = Calibrator(1,stats.norm(110,40))
c2 = Calibrator(2,stats.norm(130,20))

# %%
"""
This function generates the random numbers for the parameters being tested
"""
def π(listOfCalibrators):
    estimatesDict = {}
    for calibrator in listOfCalibrators:
        rv = calibrator.prior.rvs()
        estimatesDict[calibrator] = rv
    return estimatesDict

# %%
π([c1,c2])

# %%
"""
This function calculates the probability that the parameters are 
pulled from their distribution
"""
def π_Prior(estimatesDict):
    p = 1.0
    for calibrator,parameterValue in estimatesDict.items():
        pi = calibrator.prior.pdf(parameterValue)
        p *= pi
    return p

# %%
π_Prior(π([c1,c2]))

# %%
π_Prior({c1:1,c2:2})

# %%
"""
This function loops through a set of observations and calculates the
log-liklihood of each, summed
"""
def π_Log_Likelihood():
    return None

# %%
def MCMC():
    return None

# %%
def GA():
    return None

# %%
>>> junction = wn.get_node('121')
>>> junction.elevation = 5
>>> pipe = wn.get_link('122')
>>> pipe.diameter = pipe.diameter*0.5
>>> tank = wn.get_node('1')
>>> tank.diameter = tank.diameter*1.1

# %%
pipe

# %%
wn.links()

# %%
def waterNetworkToDataFrame():
    dfDict = {}
    
    return 0

# %%
sim = wntr.sim.EpanetSimulator(wn)

# %%
results = sim.run_sim()

# %%
pressure_at_5hr = results.node['pressure'].loc[5*3600, :]
wntr.graphics.plot_network(wn, node_attribute=pressure_at_5hr, node_size=30, 
                        title='Pressure at 5 hours')

# %%
class WNLink():
    def __init__(self,pipeToCopy):
        self.basePipe = pipeToCopy
        self.dict = pipeToCopy.todict()
        self.network = pipeToCopy.wn
    def updateNetwork(network):
        toUpdate = network.get_link(self.dict["name"])
        toUpdate.diameter = 0.5
    def __repr__(self):
        return "hello world"

# %%
b = WNLink(a)

# %%
b.dict

# %%
b

# %% [markdown]
# # Let's do this

# %% [markdown]
# For simplicity, we are treating the only system states as flow rate, and the only parameters as pipe roughness

# %% [markdown]
# ## Inputs

# %%
class Parameter():
    def __init__(self,pipeName,value,distribution=None,isFixed=True):
        self.pipeName = pipeName
        self.value = value
        self.distribution = distribution
        self.isFixed = isFixed
        
    def generateValue(self):
        return 0
    
    def probabilityOfValue(self):
        return 0

# %%
class Model():
    def __init__(self,wn,listOfParameters):
        self.wn = wn
        self.listOfParameters = listOfParameters

# %% [markdown]
# ### Fixed Inputs

# %% [markdown]
# ### Distributions of Priors

# %% [markdown]
# ### Trusted System States and their Distributions (Uncertainty) for Calibration

# %% [markdown]
# ## Methods

# %% [markdown]
# ### $\pi$- Generates the random values for the parameters being tested

# %%
def π():
    return 0

# %% [markdown]
# ### $\pi_{prior}$- Calculates the probability that a set of parameter 'states' are pulled from their distributions

# %%
def π_prior():
    return 0

# %% [markdown]
# ### $\pi_{log liklihood}$- The sum of the log liklihood of each resulting system state matching the trusted system state

# %%
def π_logLikelihood():
    return 0

# %% [markdown]
# ### MCMC

# %%
def MCMC():
    return 0

# %% [markdown]
# 1. Set the parameters for the model, both fixed and pulling from distributions
# 2. Run the model with the selected parameters
# 3. Compare model results to the "sensor" feeds
# 4. Calculate the acceptance ratio

# %% [raw]
# for parameter in wn.parameters:
#     parameterProbaility = 1.0
#     if parameter.isFixed:
#         wn.setParaemter(parameter.value)
#     else:
#         value,probability = parameter.generateProposal()
#         wn.setParameter(value)
#         parameterProbability *= probability
# results = wn.runSImulation()
# reusltsProbability = 1.0
# for calibrator in calibrators:
#     comparableResult = extractResult(results,calibrator)
#     resultProbability = calibrator.distribution.rvs(comparableResult,calibrator.value,calibrator.std)
#     resultsProbability *= resultProbability
# calculateAlpha(resultsProbability,parameterProbability)
